# %% [markdown]
# <a href="https://colab.research.google.com/github/Disha5199/SVM/blob/main/SVM_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/svm_dataset.csv")
df
# Out:
#      Num_Links  Buy_Now  Capital_Letters  Spam
# 0            6        1               26     0
# 1            3        0                1     0
# 2            7        0               89     1
# 3            4        1               16     0
# 4            6        1               32     0
# ..         ...      ...              ...   ...
# 195          7        1               81     1
# 196          4        0               95     1
# 197          3        1               23     0
# 198          1        0               22     0
# 199          5        1               61     1
#
# [200 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
